# %%
import pandas as pd
from datetime import datetime
from icecream import ic
import json

# %%
folder_path = "/mnt/data/amazon-review-v2/"
file_name = "AMAZON_FASHION.json"

# %%
with open(folder_path + file_name) as f:
    # read json file to dict
    data = json.load(f)
    #data = pd.read_json(f, lines=True)
    
data = pd.json_normalize(data)#, "style", ['Size', 'Color'])
ic(len(data))
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       1 with open(folder_path + file_name) as f:
#       2     # read json file to dict
#       5     data = pd.read_json(f, lines=True)
# ----> 6     data = pd.json_normalize(data, "style", ['Size', 'Color'])
#       7 ic(len(data))
#       8 data.head()
#
# File /opt/miniconda3/envs/tabgt/lib/python3.10/site-packages/pandas/io/json/_normalize.py:519, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     516                 meta_vals[key].append(meta_val)
#     517             records.extend(recs)
# --> 519 _recursive_extract(data, record_path, {}, level=0)
#     521 result = DataFrame(records)
#     523 if record_prefix is not None:
#
# File /opt/miniconda3/envs/tabgt/lib/python3.10/site-packages/pandas/io/json/_normalize.py:501, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     499 else:
#     500     for obj in data:
# --> 501         recs = _pull_records(obj, path[0])
#     502         recs = [
#     503             nested_to_record(r, sep=sep, max_level=max_level)
#     504             if isinstance(r, dict)
#     505             else r
#     506             for r in recs
#     507         ]
#     509         # For repeating the metadata later
#
# File /opt/miniconda3/envs/tabgt/lib/python3.10/site-packages/pandas/io/json/_normalize.py:423, in json_normalize.<locals>._pull_records(js, spec)
#     417 def _pull_records(js: dict[str, Any], spec: list | str) -> list:
#     418     """
#     419     Internal function to pull field for records, and similar to
#     420     _pull_field, but require to return list. And will raise error
#     421     if has non iterable value.
#     422     """
# --> 423     result = _pull_field(js, spec, extract_record=True)
#     425     # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#     426     # null, otherwise return an empty list
#     427     if not isinstance(result, list):
#
# File /opt/miniconda3/envs/tabgt/lib/python3.10/site-packages/pandas/io/json/_normalize.py:400, in json_normalize.<locals>._pull_field(js, spec, extract_record)
#     398             result = result[field]
#     399     else:
# --> 400         result = result[spec]
#     401 except KeyError as e:
#     402     if extract_record:
#
# TypeError: string indices must be integers

# %%
#group by asin
grouped = data.groupby('asin')
ic(len(grouped))
grouped.head()
ic(data['asin'].nunique())
# Out:
# ic| len(grouped): 186189
# ic| data['asin'].nunique(): 186189
# 186189

# %%
# group by reviewerID
grouped = data.groupby('reviewerID')
ic(len(grouped))
grouped.head()
# count unique reviewerID
ic(data['reviewerID'].nunique())
# Out:
# ic| len(grouped): 749233
# ic| data['reviewerID'].nunique(): 749233
# 749233

# %%
# convert reviewTime from M D,Y to datetime (POSIX time)
#timestamp_format = '%m %d, %Y'
#format_fn = lambda x: int(datetime.strptime(x, timestamp_format).timestamp())
#data['reviewTime'] = data['reviewTime'].apply(format_fn)
#data['reviewTime'] = pd.to_datetime(data['reviewTime'], format='%m %d, %Y')
# rename src and dest
data.rename(columns={'reviewerID': 'From ID', 'asin': 'To ID'}, inplace=True)
# style column is a json object, convert each key to a column

ic(data.tail())
data
# Out:
# ic| data.tail():         overall  verified   reviewTime         From ID       To ID  \
#                  883631        5      True  02 21, 2017  A1ZSB2Q144UTEY  B01HJHTH5U
#                  883632        5      True  11 25, 2016  A2CCDV0J5VB6F2  B01HJHTH5U
#                  883633        3      True  11 10, 2016  A3O90PACS7B61K  B01HJHTH5U
#                  883634        3      True  11 10, 2016  A2HO94I89U3LNH  B01HJHF97K
#                  883635        5      True   08 9, 2016  A2RSX9E79DUHRX  B01HJG5NMW
#
#                                 reviewerName  \
#                  883631      Amazon Customer
#                  883632      Amazon Customer
#                  883633             Fabfifty
#                  883634               Mgomez
#                  883635  Natasha Mascarenhas
#
#                                                                 reviewText  \
#                  883631  I absolutely love this dress!!  It's sexy and ...
#                  883632  I'm 5'6 175lbs. I'm on the tall side. I wear a...
#                  883633                         Too big in the chest area!
#                  883634                Too clear in the back, needs lining
#                  883635  Ordered and was slightly small. Worked with th...
#
#                                                                    summary  unixReviewTime  \
#                  883631                       I absolutely love this dress      1487635200
#                  883632  I wear a large and ordered a large and it stil...      1480032000
#                  883633                                        Three Stars      1478736000
#                  883634                                        Three Stars      1478736000
#                  883635         The quality is excellent and it is so cute      1470700800
#
#                          vote style image
#                  883631   NaN   NaN   NaN
#                  883632   2.0   NaN   NaN
#                  883633   NaN   NaN   NaN
#                  883634   NaN   NaN   NaN
#                  883635   NaN   NaN   NaN
#         overall  verified   reviewTime         From ID       To ID  \
# 0             5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1             2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2             4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3             2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4             3     False  07 27, 2014   A89F3LQADZBS5  7106116521
# ...         ...       ...          ...             ...         ...
# 883631        5      True  02 21, 2017  A1ZSB2Q144UTEY  B01HJHTH5U
# 883632        5      True  11 25, 2016  A2CCDV0J5VB6F2  B01HJHTH5U
# 883633        3      True  11 10, 2016  A3O90PACS7B61K  B01HJHTH5U
# 883634        3      True  11 10, 2016  A2HO94I89U3LNH  B01HJHF97K
# 883635        5      True   08 9, 2016  A2RSX9E79DUHRX  B01HJG5NMW
#
#                reviewerName  \
# 0                     Tracy
# 1                 Sonja Lau
# 2                  Kathleen
# 3               Jodi Stoner
# 4              Alexander D.
# ...                     ...
# 883631      Amazon Customer
# 883632      Amazon Customer
# 883633             Fabfifty
# 883634               Mgomez
# 883635  Natasha Mascarenhas
#
#                                                reviewText  \
# 0                                  Exactly what I needed.
# 1       I agree with the other review, the opening is ...
# 2       Love these... I am going to order another pack...
# 3                                     too tiny an opening
# 4                                                    Okay
# ...                                                   ...
# 883631  I absolutely love this dress!!  It's sexy and ...
# 883632  I'm 5'6 175lbs. I'm on the tall side. I wear a...
# 883633                         Too big in the chest area!
# 883634                Too clear in the back, needs lining
# 883635  Ordered and was slightly small. Worked with th...
#
#                                                   summary  unixReviewTime  \
# 0                                  perfect replacements!!      1413763200
# 1       I agree with the other review, the opening is ...      1411862400
# 2                                     My New 'Friends' !!      1408924800
# 3                                               Two Stars      1408838400
# 4                                             Three Stars      1406419200
# ...                                                   ...             ...
# 883631                       I absolutely love this dress      1487635200
# 883632  I wear a large and ordered a large and it stil...      1480032000
# 883633                                        Three Stars      1478736000
# 883634                                        Three Stars      1478736000
# 883635         The quality is excellent and it is so cute      1470700800
#
#         vote style image
# 0        NaN   NaN   NaN
# 1        3.0   NaN   NaN
# 2        NaN   NaN   NaN
# 3        NaN   NaN   NaN
# 4        NaN   NaN   NaN
# ...      ...   ...   ...
# 883631   NaN   NaN   NaN
# 883632   2.0   NaN   NaN
# 883633   NaN   NaN   NaN
# 883634   NaN   NaN   NaN
# 883635   NaN   NaN   NaN
#
# [883636 rows x 12 columns]

# %%
# store the data in a csv file
data.to_csv(folder_path + file_name + ".csv", index=False)

# %%
with open(folder_path + file_name + ".csv") as f:
    preprocessed_data = pd.read_csv(f)
ic(preprocessed_data.head())
ic(len(preprocessed_data))
# Out:
# ic| data.head():    overall  verified   reviewTime         From ID       To ID  reviewerName  \
#                  0        5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521         Tracy
#                  1        2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521     Sonja Lau
#                  2        4     False  08 25, 2014  A2MWC41EW7XL15  7106116521      Kathleen
#                  3        2      True  08 24, 2014  A2UH2QQ275NV45  7106116521   Jodi Stoner
#                  4        3     False  07 27, 2014   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                                            reviewText  \
#                  0                             Exactly what I needed.
#                  1  I agree with the other review, the opening is ...
#                  2  Love these... I am going to order another pack...
#                  3                                too tiny an opening
#                  4                                               Okay
#
#                                                               summary  unixReviewTime  vote  \
#                  0                             perfect replacements!!      1413763200   NaN
#                  1  I agree with the other review, the opening is ...      1411862400   3.0
#                  2                                My New 'Friends' !!      1408924800   NaN
#                  3                                          Two Stars      1408838400   NaN
#                  4                                        Three Stars      1406419200   NaN
#
#                    style image
#                  0   NaN   NaN
#                  1   NaN   NaN
#                  2   NaN   NaN
#                  3   NaN   NaN
#                  4   NaN   NaN
# ic| len(data): 883636
# 883636
